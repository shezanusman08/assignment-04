# %% [markdown]
# <a href="https://colab.research.google.com/github/shezanusman08/assignment-04/blob/main/00_intro_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **01_add_two_numbers**

# %%
print("01_add_two_numbers")

def add_two_numbers():
  print("This application for add two numbers")

  firts_num = int(input("Enter first number: "))
  second_num = int(input("Enter second number"))
  total = int (firts_num + second_num)
  print(f"Total is: {total} ")

if __name__ == "__main__":
  add_two_numbers();
# Out:
# 01_add_two_numbers
# This application for add two numbers
# Enter first number: 6
# Enter second number6
# Total is: 12

# %% [markdown]
# ## **02_agreement_bot**

# %%
print("02_agreement_bot")

def agreement_bot():

  animal = str(input("What is your favorite animal? "))
  print(f"My favorite animal is also {animal}")

  color = str(input("What is your favorite color? "))
  print(f"My favorite color is also {color}")

  food = str(input("What is your favorite food? "))
  print(f"My favorite food is also {food}")

if __name__ == "__main__":
  agreement_bot()
# Out:
# 02_agreement_bot
# What is your favorite animal? cat
# My favorite animal is also cat
# What is your favorite color? black
# My favorite color is also black
# What is your favorite food? biryani
# My favorite food is also biryani

# %% [markdown]
# # **03_fahrenheit_to_celsius**.

# %%
print("03_fahrenheit_to_celsius")

def fahrenheit_to_celsius():
  fahrenheit = float(input("Enter temperature in Fahrenheit: "))
  celsius = (fahrenheit - 32) * 5/9
  print(f"{fahrenheit} degrees Fahrenheit is equal to {celsius:.2f} degrees Celsius.")

if __name__ == "__main__":
  fahrenheit_to_celsius()
# Out:
# 03_fahrenheit_to_celsius
# Enter temperature in Fahrenheit: 44
# 44.0 degrees Fahrenheit is equal to 6.67 degrees Celsius.

# %% [markdown]
# # **04_how_old_are_they**

# %%
def main():
    anton : int = 21
    beth : int = 6 + anton
    chen : int = 20 + beth
    drew  : int= chen + anton
    ethan : int = chen

   # Print out all of the ages!
    print("Anton is " + str(anton))
    print("Beth is " + str(beth))
    print("Chen is " + str(chen))
    print("Drew is " + str(drew))
    print("Ethan is " + str(ethan))


# There is no need to edit code beyond this point

if __name__ == '__main__':
    main()
# Out:
# Anton is 21
# Beth is 27
# Chen is 47
# Drew is 68
# Ethan is 47

# %% [markdown]
# # **05_triangle_parameter**

# %%
def triangle_parameter():
  side1 = float(input("Enter the length of the first side: "))
  side2 = float(input("Enter the length of the second side: "))
  side3 = float(input("Enter the length of the third side: " ))

  print("The perimeter of the triangle is " + str(side1 + side2 + side3))

if __name__ == "__main__":
  triangle_parameter()
# Out:
# Enter the length of the first side: 3
# Enter the length of the second side: 3
# Enter the length of the third side: 6
# The perimeter of the triangle is 12.0

# %% [markdown]
# # **06_square_number**

# %%
def square_number():
  number: float = float(input("Enter a number for square: "))
  print(f"The square of {number} is {number ** 2}")

if __name__ == "__main__":
  square_number()
# Out:
# Enter a number for square: 55
# The square of 55.0 is 3025.0

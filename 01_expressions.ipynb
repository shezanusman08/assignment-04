# %% [markdown]
# <a href="https://colab.research.google.com/github/shezanusman08/assignment-04/blob/main/01_expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **01_Dicesimulator**

# %%
import random

def roll_dice():
    dice1: int = random.randint(1, 6)
    dice2: int = random.randint(1, 6)

    total: int = dice1 + dice2

    print(f"Dice 1: {dice1}")
    print(f"Dice 2: {dice2}")
    print(f"Total of two dice is: {total}")

def main():
    diec1: int = 10
    print(f"Dice 1 in main() start as: {diec1}")

    roll_dice()
    roll_dice()
    roll_dice()

    print(f"Dice 1 in main() end as: {diec1}")

if __name__ == "__main__":
    main()
# Out:
# Dice 1 in main() start as: 10
# Dice 1: 1
# Dice 2: 3
# Total of two dice is: 4
# Dice 1: 5
# Dice 2: 5
# Total of two dice is: 10
# Dice 1: 3
# Dice 2: 6
# Total of two dice is: 9
# Dice 1 in main() end as: 10

# %% [markdown]
# # **02_E=mc2**

# %%
C: int = 299792458

def main():
    mass_in_kg: float = float(input("Enter kilos of mass: "))

    energy_in_joules: float = mass_in_kg * (C ** 2)

    print("e = m * C^2...")
    print("m = " + str(mass_in_kg) + " kg")
    print("C = " + str(C) + " m/s")

    print(str(energy_in_joules) + " joules of energy!")



if __name__ == '__main__':
    main()
# Out:
# Enter kilos of mass: 130
# e = m * C^2...
# m = 130.0 kg
# C = 299792458 m/s
# 1.1683817323578628e+19 joules of energy!

# %% [markdown]
# # **03_foot_to_inches**

# %%
inch: int =12

def foot():
  feet:int = int(input("Enter feet and i will convert it to inches: "))
  print(f"There are {inch * feet} inches in {feet} feet.")

if __name__ == '__main__':
  foot()
# Out:
# Enter feet and i will convert it to inches: 33
# There are 396 inches in 33 feet.

# %% [markdown]
# # **04_pythagorean_theorem**

# %%
import math

def triangle():
  ab:float = float(input("Enter the length of side ab: "))
  ac:float = float(input("Enter the length of side ac: "))
  bc:float = math.sqrt(ab**2 + ac**2)

  print(f"The length of bc (the hypotheus is: {bc})")

if __name__ == '__main__':
  triangle()
# Out:
# Enter the length of side ab: 2
# Enter the length of side ac: 7
# The length of bc (the hypotheus is: 7.280109889280518)

# %% [markdown]
# # **05_remainder_division**

# %%
def remainder():

  num1:int = int(input("Enter firts number: "))
  num2:int = int(input("Enter second number: "))
  quotient: int = num1 // num2
  print(f"The quotient of {num1} divided by {num2} is {quotient}")
  remainder: int = num1 % num2
  print(f"The remainder of {num1} divided by {num2} is {remainder}")

if __name__ == "__main__":
  remainder()
# Out:
# Enter firts number: 6
# Enter second number: 9
# The quotient of 6 divided by 9 is 0
# The remainder of 6 divided by 9 is 6

# %% [markdown]
# # **06_rolldice**

# %%
import random

NUM_SIDES: int = 6

def main():

    die1: int = random.randint(1, NUM_SIDES)
    die2: int = random.randint(1, NUM_SIDES)

    # Get their total
    total: int = die1 + die2

    print("Dice have", NUM_SIDES, "sides each.")
    print("First die:", die1)
    print("Second die:", die2)
    print("Total of two dice:", total)



if __name__ == '__main__':
    main()
# Out:
# Dice have 6 sides each.
# First die: 6
# Second die: 1
# Total of two dice: 7

# %% [markdown]
# # **06_seconds_in_year**

# %%
def seconds_in_year():

  day_per_year = 365
  hour_per_day = 24
  minute_per_hour = 60
  second_per_minute = 60

  print(f"There are {day_per_year * hour_per_day * minute_per_hour * second_per_minute} seconds in a year.")

if __name__ == '__main__':
  seconds_in_year()
# Out:
# There are 31536000 seconds in a year.

# %% [markdown]
# # **07_tiny_mad_lib**

# %%
Sentence = "Panaversity is fun. I learned to program and used Python to make my "
def tiny_mad_lib():

    adjective: str = input("Please type an adjective and press enter. ")
    noun: str = input("Please type a noun and press enter. ")
    verb: str = input("Please type a verb and press enter. ")

    print(Sentence + adjective + " " + noun + " " + verb + "!")

if __name__ == '__main__':
    tiny_mad_lib()
# Out:
# Please type an adjective and press enter. amazing
# Please type a noun and press enter. projects
# Please type a verb and press enter. build
# Panaversity is fun. I learned to program and used Python to make my amazing projects  build!
